# %%
import numpy as np
import pandas as pd
import matplotlib as matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split
# %matplotlib inline
sns.set()

# %%
from sklearn.datasets import load_wine
data1=load_wine()

# %%
df1=pd.DataFrame(data1.data,columns=data1.feature_names)

# %%
df1.target.shape

# %%
df1.columns.values
# Out:
# array(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline'], dtype=object)

# %%
df1
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df1.tail(7)
df1.head(7)
df1.sample(7)
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 38     13.07        1.50  2.10               15.5       98.0           2.40
# 164    13.78        2.76  2.30               22.0       90.0           1.35
# 177    14.13        4.10  2.74               24.5       96.0           2.05
# 47     13.90        1.68  2.12               16.0      101.0           3.10
# 156    13.84        4.12  2.38               19.5       89.0           1.80
# 28     13.87        1.90  2.80               19.4      107.0           2.95
# 134    12.51        1.24  2.25               17.5       85.0           2.00
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 38         2.64                  0.28             1.37             3.70  1.18
# 164        0.68                  0.41             1.03             9.58  0.70
# 177        0.76                  0.56             1.35             9.20  0.61
# ...

# %%
df1.isnull().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# dtype: int64

# %%
df1.dtypes
# Out:
# alcohol                         float64
# malic_acid                      float64
# ash                             float64
# alcalinity_of_ash               float64
# magnesium                       float64
# total_phenols                   float64
# flavanoids                      float64
# nonflavanoid_phenols            float64
# proanthocyanins                 float64
# color_intensity                 float64
# hue                             float64
# od280/od315_of_diluted_wines    float64
# proline                         float64
# dtype: object

# %%
import matplotlib as matplotlib
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize =(18,18))      #3.a
ax.hist(df1['alcohol'], bins =25)
plt.show()

fig, ax = plt.subplots(figsize =(18,18))      #3.a
ax.hist(df1['malic_acid'], bins =25)
plt.show()

fig, ax = plt.subplots(figsize =(18,18))      #3.a
ax.hist(df1['ash'], bins =25)
plt.show()

fig, ax = plt.subplots(figsize =(18,18))      #3.a
ax.hist(df1['alcalinity_of_ash'], bins =25)
plt.show()

fig, ax = plt.subplots(figsize =(18,18))      #3.a
ax.hist(df1['magnesium'], bins =25)
plt.show()

fig, ax = plt.subplots(figsize =(18,18))      #3.a
ax.hist(df1['total_phenols'], bins =25)
plt.show()

fig, ax = plt.subplots(figsize =(18,18))      #3.a
ax.hist(df1['flavanoids'], bins =25)
plt.show()

fig, ax = plt.subplots(figsize =(18,18))      #3.a
ax.hist(df1['nonflavanoid_phenols'], bins =25)
plt.show()

fig, ax = plt.subplots(figsize =(18,18))      #3.a
ax.hist(df1['proanthocyanins'], bins =25)
plt.show()

fig, ax = plt.subplots(figsize =(18,18))      #3.a
ax.hist(df1['color_intensity'], bins =25)
plt.show()

fig, ax = plt.subplots(figsize =(18,18))      #3.a
ax.hist(df1['hue'], bins =25)
plt.show()

fig, ax = plt.subplots(figsize =(18,18))      #3.a
ax.hist(df1['od280/od315_of_diluted_wines'], bins =25)
plt.show()

fig, ax = plt.subplots(figsize =(18,18))      #3.a
ax.hist(df1['proline'], bins =25)
plt.show()

# %%
fig,ax=plt.subplots(1,3,figsize=(17,5))
for i in range(3):
    sns.regplot(data=df1,x=df1.columns[i],y=df1.columns[-1],ax=ax[i])
    corr=df1[df1.columns[i]].corr(df1[df1.columns[-1]])
    ax[i].set_title(corr)

# %%
x = df1['alcohol']
y = df1['proline']

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=100)

# %%
X_train, X_test = X_train.values, X_test.values  
X_train= X_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)

# %%
lr = LinearRegression()   
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_mean = np.mean(x)
Y_mean = np.mean(y)

num = 0
den = 0
for i in range(len(x)):
    num += (x[i] - X_mean)*(y[i] - Y_mean)
    den += (x[i] - X_mean)**2
m = num / den
c = Y_mean - m*X_mean

print (m, c)
# Out:
# 249.69897085050434 -2499.347670982363

# %%
predictions = lr.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 207.62758444788437
# MSE: 65169.13491549557
# RMSE: 255.28246104167746

# %%
x=df1[df1.columns[:-1]]
y=df1['proline']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
x_train, x_test = x_train.values, x_test.values
reg = LinearRegression()
reg.fit(x_train,y_train)
y_predict=reg.predict(x_test)
print(reg.coef_)
print(reg.intercept_)
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# [ 128.70327779  -21.49575141  162.07269532  -20.44406099    2.68846459
#    -1.2838999    42.46404404 -170.96759699    6.10483203   41.61358074
#   237.06454913   29.55043403]
# -1668.7067383576446
# MAE: 267.69461981688414
# MSE: 124847.74311337715
# RMSE: 353.33800123023445

# %% [markdown]
# in SLR errors are low campared to MLR
